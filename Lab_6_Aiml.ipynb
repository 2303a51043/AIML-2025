# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51043/AIML-2025/blob/main/Lab_6_Aiml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pt
from google.colab import files
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ** Part 1: Import the required Python,Pandas,Matplotlib,Seaborn packages**

# %%
# 1. Upload the file using Google Colab uploader
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0ef9643c-2f3b-4568-a6af-3e3562af937e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ef9643c-2f3b-4568-a6af-3e3562af937e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 2. Load the classified dataset into a dataframe using pandas
a = pd.read_csv('Iris - all-numbers.csv', index_col=0)

# %%
# 3. Check the data types of each feature (column) in the dataset
print("Data Types of Each Feature:")
print(a.dtypes)
# Out:
# Data Types of Each Feature:
# 3.5    float64
# 1.4    float64
# 0.2    float64
# 0        int64
# dtype: object

# %%
# 4. Generate a summary of the dataset for min, max, stddev, quartile values for 25%, 50%, 75%, 90%
print("\nSummary Statistics of the Dataset (including quartiles):")
print(a.describe(percentiles=[.25, .5, .75, .90]))
# Out:
# Summary Statistics of the Dataset (including quartiles):
#               3.5         1.4         0.2           0
# count  149.000000  149.000000  149.000000  149.000000
# mean     3.051007    3.774497    1.205369    1.006711
# std      0.433499    1.759651    0.761292    0.817847
# min      2.000000    1.000000    0.100000    0.000000
# 25%      2.800000    1.600000    0.300000    0.000000
# 50%      3.000000    4.400000    1.300000    1.000000
# 75%      3.300000    5.100000    1.800000    2.000000
# 90%      3.620000    5.800000    2.200000    2.000000
# max      4.400000    6.900000    2.500000    2.000000

# %%
# Get the list of columns (excluding the target and possibly irrelevant columns)
ls = list(a.columns)
# Visualize pairplot of the dataset (might be slow for large datasets)
sns.pairplot(a)

# %%
for i in range(len(ls)-1):
  sns.boxplot(x='0', y=ls[i], data=a)
  pt.show()

# %%
# 6. Scale the features using StandardScaler and transform the data (excluding the 'TARGET CLASS' column)
